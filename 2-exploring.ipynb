# %% [markdown]
# <div style="text-align: center; background-color: #5A96E3; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 02 - Data exploring
# </div>

# %% [markdown]
# **Import necesary libraries**

# %%
import warnings 
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# **Read from csv**

# %%
df = pd.read_csv("Data/survey.csv")
df.head(5)
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# ...

# %% [markdown]
# **How many rows and columns in dataframe?**

# %%
nrows, ncols = df.shape
nrows, ncols
# Out:
# (1433, 63)

# %% [markdown]
# **What is the meaning of each row?**

# %% [markdown]
# + Mỗi dòng sẽ thể hiện các thông tin về thái độ của nhân viên đối với sức khỏe tinh thần tại môi trường làm việc liên quan đến công nghệ thông tin và các thông tin của nhân viên - người tham gia trả lời khảo sát.

# %% [markdown]
# **Are there duplicated rows?**

# %%
is_duplicate = df.duplicated().sum()
if is_duplicate:
    print(f"Data have duplicated {is_duplicate} rows.")
else:
    print(f"Data have no duplicated row.")
# Out:
# Data have no duplicated row.

# %% [markdown]
# **What is the meaning of columns?**
# + Ý nghĩa của từng cột liên đới đến những câu hỏi được đặt ra trong mẫu khảo sát.

# %%
print(df.columns)
# Out:
# Index(['Are you self-employed?',
#        'How many employees does your company or organization have?',
#        'Is your employer primarily a tech company/organization?',
#        'Is your primary role within your company related to tech/IT?',
#        'Does your employer provide mental health benefits as part of healthcare coverage?',
#        'Do you know the options for mental health care available under your employer-provided coverage?',
#        'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#        'Does your employer offer resources to learn more about mental health concerns and options for seeking help?',
#        'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#        'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:',
# ...

# %% [markdown]
# **What is the current data type of each column? Are there
# columns having inappropriate data types?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 63 columns):
#  #   Column                                                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                                                            --------------  -----
#  0   Are you self-employed?                                                                                                                                                            1433 non-null   int64
#  1   How many employees does your company or organization have?                                                                                                                        1146 non-null   object
# ...

# %% [markdown]
# ### With each numerical column, how are values distributed?

# %%
df.describe()
# Out:
#        Are you self-employed?  \
# count             1433.000000
# mean                 0.200279
# std                  0.400349
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                  1.000000
#
#        Is your employer primarily a tech company/organization?  \
# count                                        1146.000000
# mean                                            0.770506
# std                                             0.420691
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        Is your primary role within your company related to tech/IT?  \
# count                                         263.000000
# ...

# %% [markdown]
# **What is the percentage of missing values?**

# %%
num_df = df.select_dtypes(include=["number"])
def percent_missing(series): 
    return series.isnull().sum() * 100 / len(series)
print("The percentage of missing values in each columns:")
num_df.agg(percent_missing)
# Out:
# The percentage of missing values in each columns:
# Are you self-employed?                                                                                                    0.000000
# Is your employer primarily a tech company/organization?                                                                  20.027913
# Is your primary role within your company related to tech/IT?                                                             81.646895
# Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?    79.972087
# Do you have previous employers?                                                                                           0.000000
# Have you ever sought treatment for a mental health issue from a mental health professional?                               0.000000
# What is your age?                                                                                                         0.000000
# dtype: float64

# %% [markdown]
# **Min? max? Are they abnormal?**

# %%
num_df.agg([min, max])
# Out:
#      Are you self-employed?  \
# min                       0
# max                       1
#
#      Is your employer primarily a tech company/organization?  \
# min                                                0.0
# max                                                1.0
#
#      Is your primary role within your company related to tech/IT?  \
# min                                                0.0
# max                                                1.0
#
#      Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?  \
# min                                                0.0
# max                                                1.0
#
#      Do you have previous employers?  \
# min                                0
# max                                1
#
#      Have you ever sought treatment for a mental health issue from a mental health professional?  \
# min                                                  0
# ...

# %% [markdown]
# Dữ liệu về tuổi có dấu hiệu bất thường:
# + `max = 99999999999` thì không phù hợp với thực tế.
# + `min = -1726` là dữ liệu sai vì tuổi không tồn tại giá trị âm.

# %% [markdown]
# ### With each categorical column, how are values distributed?

# %%
df.describe(include='O')
# Out:
#        How many employees does your company or organization have?  \
# count                                                1146
# unique                                                  6
# top                                                26-100
# freq                                                  292
#
#        Does your employer provide mental health benefits as part of healthcare coverage?  \
# count                                                1146
# unique                                                  4
# top                                                   Yes
# freq                                                  531
#
#        Do you know the options for mental health care available under your employer-provided coverage?  \
# count                                                1013
# unique                                                  3
# top                                                    No
# freq                                                  354
#
# ...

# %% [markdown]
# **What is the percentage of missing values?**

# %%
cate_df = df.select_dtypes(exclude=["number"])
def percent_missing(series): 
    return series.isnull().sum() * 100 / len(series)
print("The percentage of missing values in each columns:")
cate_df.agg(percent_missing)
# Out:
# The percentage of missing values in each columns:
# How many employees does your company or organization have?                                                                                                                          20.027913
# Does your employer provide mental health benefits as part of healthcare coverage?                                                                                                   20.027913
# Do you know the options for mental health care available under your employer-provided coverage?                                                                                     29.309142
# Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?                                              20.027913
# ...

# %% [markdown]
# **How many different values? Show a few**

# %%
print("The number of unique values in each column:")
cate_df.nunique()
# Out:
# The number of unique values in each column:
# How many employees does your company or organization have?                                                                                                                             6
# Does your employer provide mental health benefits as part of healthcare coverage?                                                                                                      4
# Do you know the options for mental health care available under your employer-provided coverage?                                                                                        3
# Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?                                                 3
# Does your employer offer resources to learn more about mental health concerns and options for seeking help?                                                                            3
# ...

# %%
print("Some of the unique values in 'How many employees does your company or organization have?' column:")
print(df['How many employees does your company or organization have?'].unique())
# Out:
# Some of the unique values in 'How many employees does your company or organization have?' column:
# ['26-100' '6-25' nan 'More than 1000' '100-500' '500-1000' '1-5']

# %% [markdown]
# **Are they abnormal?**

# %% [markdown]
# Các cột dữ liệu có vẻ không có gì bất thường, một số cột có tỷ lệ giá trị trống khá lớn (có thể loại bỏ trong quá trình phân tích vì không mang đến quá nhiều ý nghĩa khi thống kê)
